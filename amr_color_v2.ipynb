# %%
% pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# Step 1: Initialize coarse grid, domain [0,1]
# We have mx cells, indexed by 0 to mx-1, and x[i] is the mid-point of cell i
mxc = 100
dx = 1./mxc
xc = linspace(dx/2, 1.-dx/2, mxc)  # computational grid

tfinal = 1
dt = dx
nsteps = int(tfinal/dx)
#dt = float(tfinal)/nsteps

# intital condition
q0 = where(abs(xc) < 0.5,  1., 0.)

# Coefficient function u
def u_fnc(x):
    u = where(abs(x) < 0.5,  exp(x), 1.)
    #u = where(abs(x) < 0.5,  x**2, 0.1)
    #n = len(x)
    #n = numpy.array([x]).size
    #u = zeros(n)
    #for i in range(n):
     #   u[i]= 0.75
    
    return u

# %%
# Step 2: Solve problem for ONE time step on coarse grid, for time step dt and 2*dt
# u is the coefficient function in the form of a vector where u[i] = u(x) evaluated at x[i]
# Similarly, q0 is a vector with the initial condition evaluated at cell mid-points x[i]
# THE SOLUTION INCLUDES TWO GHOST CELLS ON EACH SIDE

def color_onestep(u,q0,dt,dx):
    
    mx = len(q0)
    qn = hstack([0,0, q0, 0,0])   # add two ghost cells on each end
                                  # qn[2] through qn[mx+1]
    #print dx
    #print dt
    cfl = abs(u)*dt/dx
    #print 'cfl', cfl

    # Extrapolate boundary conditions
    qn[0] = qn[2]
    qn[1] = qn[2]
    qn[mx+2] = qn[mx+1]
    qn[mx+3] = qn[mx+1]
    
    qnp = zeros(qn.shape)   # initialize array
    flux = zeros(qn.shape)
    
    for i in range(2,mx+2):
        flux[i] = 0.5*abs(u[i-2])*(1-(dt/dx)*abs(u[i-2]))*(qn[i]-qn[i-1])
    
    flux[0] = flux[2]
    flux[1] = flux[2]
    flux[mx+2] = flux[mx+1]
    flux[mx+3] = flux[mx+1]
        
    for i in range(2,mx+2):
        if u[i-2] > 0:
            qnp[i] = qn[i] - (dt/dx) * u[i-2]*(qn[i]-qn[i-1])
        else:
            qnp[i] = qn[i] - (dt/dx) * u[i-2]*(qn[i+1]-qn[i])
            
        qnp[i] = qnp[i]-(dt/dx)*(flux[i+1]-flux[i])
        
    #qnew = qnp[2:(mx+2)]   # throw away ghost cells
    # Extrapolate boundary conditions
    qnp[0] = qnp[2]
    qnp[1] = qnp[2]
    qnp[mx+2] = qnp[mx+1]
    qnp[mx+3] = qnp[mx+1]
    
    return qnp

# %%
def bilin_interp(x_l,x_r,y_b,y_t,ql_b,qr_b,ql_t,qr_t,in_x,in_y):
    value = (1/((x_r-x_l)*(y_t-y_b)))*(ql_b*(x_r-in_x)*(y_t-in_y) + qr_b*(in_x-x_l)*(y_t-in_y) + ql_t*(x_r-in_x)*(in_y-y_b) + qr_t*(in_x-x_l)*(in_y-y_b))
    return value

# %%
def amr_color(u_fnc,q0,xc,tfinal,nsteps):
    # q0 = initial condition evaluated on coarse grid 
    # u_fnc = a function name evaluating the coefficient function u at the grid points
    # xc = coarse grid, domain [a,b] is divided into mx_c cells, and xc[i] is the mid-point of cell i
        
    dx = xc[1]- xc[0]             # length of cells in (given) coasrse grid
    dt = float(tfinal)/nsteps     # length of time-step
    
    u = u_fnc(xc)
    # u = velocity (coefficient) function, u[i] is cell-centered value in cell [i],
    #     currently evaluated at cell-midpoint
    
    mx_c = len(xc)              # number of grid cells in coarse grid
    
    qn = hstack([0,0,q0,0,0])
    qn[0] = qn[2]
    qn[1] = qn[2]
    qn[mx_c+2] = qn[mx_c+1]
    qn[mx_c+3] = qn[mx_c+1]
    
    # Step 1: initalize coarse grid values q0 and u: Done before calling this function
    
    
    # The rest of the steps are done over nsteps/K time steps, where K is the the period for regridding
    for istep in range(nsteps):
        
        # Step 2: Solve problem on coarse grid for single time step
        #         Done by calling a function 'color_onestep', which advances the solution on a grid
        #         with spacing dx, over a single time step of length dt, returns solution with two ghost cell
        #         values on each side
        
        qnp = color_onestep(u,qn[2:mx_c+2],dt,dx)
    
        # Step 3: Estimate error and flag cells based on Richardson extrapolation
        #         We only allow for single level refinement.
        # This estimation and grid generation procedure is only performed every K time steps. Buffer zone size and K
        # are inter-related.
    
        qnew_D2 = (color_onestep(u,qnp[2:mx_c+2],dt,dx)[2:mx_c+2])   # twice
        qnew_2D = (color_onestep(u,qn[2:mx_c+2],2*dt,dx)[2:mx_c+2])  # double time step

        # Error
        error = zeros(mx_c)
        s = 2             # order of accuracy
        flag_cnt = 0      # flagged cell count
        tol = (dx**(s+2))/1000

        for i in range(0,mx_c):
            error[i] = (qnew_D2[i]-qnew_2D[i])/(2**(s+1)-2) # returned solutions had ghost cells
            if abs(error[i]) >= tol:
                flag_cnt = flag_cnt + 1
        
        print flag_cnt, 'number of flagged cells'
        
        # Use AMR only if any cells are flagged for refinement!
        if flag_cnt > 0:
            
            # Cell flagging
            flagged = zeros(flag_cnt)  # contains indices of cells flagged for refinement

            flag_cnt = 0
            for i in range(0,mx_c):
                if abs(error[i]) >= tol:
                    flagged[flag_cnt] = i
                    flag_cnt = flag_cnt + 1
            print flagged
   
            # cluster generation
            bfs = 2 # buffer-size
            gc = 1  # number of ghost cells
            cls_tol = 2*(bfs+gc) # threshold for clustering
    
            temp = zeros(2*flag_cnt) # will be storing start and end points of clusters here
            idx = 0
            temp[idx] = max(flagged[0]-bfs,0.) # lower end of first cluster
            clstr_cnt = 0

            for i in range(0,flag_cnt-1):
                if (flagged[i+1]-flagged[i]) > cls_tol:
                    temp[idx+1] = flagged[i] + bfs  # upper end of (s/2 + 1)th cluster
                    clstr_cnt = clstr_cnt + 1
                    idx = idx+2
                    temp[idx] = flagged[i+1] - bfs

            temp[idx+1] = min(flagged[flag_cnt-1]+ bfs, mx_c-1)
            clstr_cnt = clstr_cnt + 1
            clstr_cnt = int(clstr_cnt)

            clusters = [0 for i in xrange(2*clstr_cnt)]

            for i in range(0,2*clstr_cnt):
                clusters[i] = int(temp[i])
            #print clusters
    
            # Generate fine grid
            # clstr_cnt = number of clusters
            R = 2 # refinement factor
            dx_hat = dx/R 
            dt_hat = dt/R
        
        
            # Look for the largest sized cluster, to create array qhat of appropriate size
            cellnum = [0 for i in xrange(clstr_cnt)]  # Array to store number of cells in each cluster, sans ghost cells.
            
            for i in range(0,clstr_cnt):
                cellnum[i] = int(clusters[(2*i)+1] - clusters[2*i]) +1
            maxclsize = max(cellnum)
   
            max_f = R*maxclsize                # maximum number of fine grid cells in any cluster
            
            qhat = zeros([clstr_cnt,max_f+4])  # include two ghost cells (on fine grid) on either side of each cluster
                                               # so, one coarse grid cell on each side as ghost cell
            xhat = zeros([clstr_cnt,max_f+4])
        
            corr_l = zeros(clstr_cnt)   # store correction terms for fix up step
            corr_r = zeros(clstr_cnt)
    
        
            for iclstr in range(0,clstr_cnt):
                
                
                clidx = range(clusters[(2*iclstr)]-1, clusters[(2*iclstr)+1]+2)
                print 'start of cluster', clusters[(2*iclstr)]
                print 'end of cluster' ,clusters[(2*iclstr)+1]
                print clidx[0], clidx[cellnum[iclstr]+1]
                # vector of cellnum + 2 coarse cell indices in cluster iclstr
                # (could start at -1, if the first cell in the first cluster is 0, which is fine
                # since we already have ghost cell values stored in qn and qnp; in fact, qn[1] and qnp[1]
                # correspond to function values in cell '-1' on coarse grid. The value for cell j is stored in 
                # qn[j+2] and qnp[j+2])
                
                mxf_clstr = 2*(cellnum[iclstr] + 2) # number of fine grid cells in cluster
                print 'cluster, fine grid size', iclstr, mxf_clstr
                
                # cell midpoints for fine grid
                
                # Left fine grid ghost-cells (may be out of domain)
                xhat[iclstr,0] = xc[clidx[1]]-(5*dx)/4      
                xhat[iclstr,1] = xc[clidx[1]]-(3*dx/4)
                
                # Right ghost cells
                print iclstr,mxf_clstr-2, clidx[cellnum[iclstr]]
                xhat[iclstr,mxf_clstr-2] = xc[clidx[cellnum[iclstr]]]+(3*dx)/4
                xhat[iclstr,mxf_clstr-1] = xc[clidx[cellnum[iclstr]]]+(5*dx)/4
                
                for j in range(1,cellnum[iclstr]+1):
                    xhat[iclstr,2*j]   = xc[clidx[j]]-(dx)/4
                    xhat[iclstr,2*j+1] = xc[clidx[j]]+(dx)/4
                 
                # Initializing fine grid q values (including ghost cells)
                for j in range(0,cellnum[iclstr]+2):
                
                    slope1 = (qn[clidx[j]+2] - qn[clidx[j]])/dx
                    slope2 = (qn[clidx[j]+2] - qn[clidx[j]])/dx
                    if (slope1*slope2)<= 0:
                        slope = 0
                    elif slope1 > 0:
                        slope = min(slope1,slope2)
                    else:
                        slope = max(slope1,slope2)
                    # minmod slope. can use other slopes, limiters, etc
                    
                    qhat[iclstr,2*j]   = qn[clidx[j]+2] - slope*(dx)/4
                    qhat[iclstr,2*j+1] = qn[clidx[j]+2] + slope*(dx)/4
                
                #plot(xc,q0,xhat[0:mxf_clstr],qhat[0:mxf_clstr])
                #plt.show
                #raw_input('Press <ENTER> to continue')
                
                uhat = u_fnc(xhat[iclstr,0:mxf_clstr])
                
                print 'len(uhat), len(qhat)' , len(uhat), mxf_clstr
            
                for tstep in range(0,R):
                                    
                    # compute correction for this fine grid time step
                    # Fix-up in ghost cells to ensure conservation
                    # Left ghost cell, indexed by clidx[0]
                    
                    u_lgc_l = u_fnc(xhat[iclstr,0])
                    u_lgc_r = u_fnc(xhat[iclstr,1])
                                
                    if u_lgc_l >= 0: # Right going correction
                        corr_l[iclstr] = corr_l[iclstr] + (dt_hat/dx) * u_lgc_l*(qnp[clidx[0]+2]- qhat[iclstr,0])    
                    # if u_lgc_l < 0: # Left going correction, nothing to do                
                
                    # if u_lgc_r >= 0: # Right going correction, nothing to do
                    if u_lgc_r < 0: # Left going correction
                        corr_l[iclstr] = corr_l[iclstr] + (dt_hat/dx) * u_lgc_r*(qhat[iclstr,1] - qnp[clidx[0]+2]) 
            
                    # Right ghost cell, indexed by clidx[cellnum[iclstr]+1]
                    u_rgc_l = u_fnc(xhat[iclstr,mxf_clstr-2])
                    u_rgc_r = u_fnc(xhat[iclstr,mxf_clstr-1])
            
                    if u_rgc_l >= 0: # Right going correction
                        corr_r[iclstr] = corr_r[iclstr] + (dt_hat/dx) * u_rgc_l*(qnp[clidx[cellnum[iclstr]]+2]- \
                                                                                 qhat[iclstr,mxf_clstr-2])
                    # if u_rgc_l < 0: # Left going correction, nothing to do
                  
                    # if u_rgc_r >= 0: # Right going correction, nothing to do
                    if u_rgc_r < 0: # Left going correction
                        corr_r[iclstr] = corr_r[iclstr] + (dt_hat/dx) * u_rgc_r*(qhat[iclstr,mxf_clstr-1]- \
                                                                                 qnp[clidx[cellnum[iclstr]]+2])
                
                
                    # Compute qhat for time t_n + dt_hat
                    qhat[iclstr,0:mxf_clstr] = color_onestep(uhat,qhat[iclstr,0:mxf_clstr],dt_hat,dx_hat)[2:mxf_clstr+2]
            
                    
                    # bilin_interp(x_l,x_r,y_b,y_t,ql_b,qr_b,ql_t,qr_t,in_x,in_y)
            
                    qhat[iclstr,0] = bilin_interp(xc[clidx[1]]-2*dx,
                                                  xc[clidx[1]]-dx,
                                                  0,
                                                  dt,
                                                  qn[clidx[0]+1],
                                                  qn[clidx[0]+2],
                                                  qnp[clidx[0]+1],
                                                  qnp[clidx[0]+2],
                                                  xc[clidx[1]]-(5*dx/4),
                                                  dt_hat)
                    #print ' qhat[iclstr,0]', qhat[iclstr,0]
                    qhat[iclstr,1] = bilin_interp(xc[clidx[1]]-dx,
                                                  xc[clidx[1]],
                                                  0,
                                                  dt,
                                                  qn[clidx[0]+2],
                                                  qn[clidx[1]+2],
                                                  qnp[clidx[0]+2] ,
                                                  qnp[clidx[1]+2],
                                                  xc[clidx[1]]-(3*dx/4),
                                                  dt_hat)
                    #print 'qhat[iclstr,1]',qhat[iclstr,1]
                    
                    qhat[iclstr,mxf_clstr-2] = bilin_interp(xc[clidx[cellnum[iclstr]]],
                                                            xc[clidx[cellnum[iclstr]]]+dx,
                                                            0,
                                                            dt,
                                                            qn[clidx[cellnum[iclstr]]+2],
                                                            qn[clidx[cellnum[iclstr]]+3],
                                                            qnp[clidx[cellnum[iclstr]]+2],
                                                            qnp[clidx[cellnum[iclstr]]+3],
                                                            xc[clidx[cellnum[iclstr]]]+(3*dx/4),
                                                            dt_hat)
                    #print 'qhat[iclstr,mxf_clstr-2]',qhat[iclstr,mxf_clstr-2]
                    
                    qhat[iclstr,mxf_clstr-1] = bilin_interp(xc[clidx[cellnum[iclstr]]]+dx,
                                                            xc[clidx[cellnum[iclstr]]]+2*dx,
                                                            0,
                                                            dt,
                                                            qn[clidx[cellnum[iclstr]]+3],
                                                            qn[clidx[cellnum[iclstr]]+4],
                                                            qnp[clidx[cellnum[iclstr]]+3],
                                                            qnp[clidx[cellnum[iclstr]]+4] ,
                                                            xc[clidx[cellnum[iclstr]]]+(5*dx/4),
                                                            dt_hat)
                    #print 'qhat[iclstr,mxf_clstr-1]', qhat[iclstr,mxf_clstr-1]
            
                    # Solve over another time step dt_hat to get fine grid values for time t_n+1
                    qhat[iclstr,0:mxf_clstr] = color_onestep(uhat,qhat[iclstr,0:mxf_clstr],dt_hat,dx_hat)[2:mxf_clstr+2]
                
                # Add corrections to function values in the ghost cells at time t_(n+1)
                qnp[clidx[0]+2] = qnp[clidx[0]+2] + corr_l[iclstr]
                qnp[clidx[cellnum[iclstr]+1]+2] = qnp[clidx[cellnum[iclstr]+1]+2] + corr_r[iclstr]
            
                # Average to get coarse grid values within fine grid region
                for k in range(1,cellnum[iclstr]+1):
                    a = 0
                    for icell in range(0,R):
                        a = a + qhat[iclstr, R*k +icell]
                        
                    qnp[clidx[k]+2] = a/R
        
        
        # updated values for next time step iteration
        #print 'qn'
        #print qn
        
        #print 'qnp'
        #print qnp
        qn = qnp
        
        plt.figure(istep) 
        plot(xc,qn[2:mx_c+2])
        ylim([-0.5,1.5])
        plt.show()
    return qn[2:mx_c+2]

# %%
#plot(xc,u_fnc(xc))
qfinal = amr_color(u_fnc,q0,xc,tfinal,nsteps)
plot(xc,qfinal)
ylim([-0.5,1.5])
# Out:
# 3 number of flagged cells
# [ 49.  50.  51.]
# start of cluster 47
# end of cluster 53
# 46 54
# cluster, fine grid size 0 18
# 0 16 53
# len(uhat), len(qhat) 18 18
# 3 number of flagged cells
# [ 51.  52.  53.]
# start of cluster 49
# end of cluster 55
# 48 56
# cluster, fine grid size 0 18
# 0 16 55
# len(uhat), len(qhat) 18 18
# 3 number of flagged cells
# [ 53.  54.  55.]
# start of cluster 51
# end of cluster 57
# 50 58
# cluster, fine grid size 0 18
# 0 16 57
# len(uhat), len(qhat) 18 18
# 3 number of flagged cells
# [ 55.  56.  57.]
# start of cluster 53
# end of cluster 59
# 52 60
# cluster, fine grid size 0 18
# 0 16 59
# len(uhat), len(qhat) 18 18
# 3 number of flagged cells
# [ 57.  58.  59.]
# start of cluster 55
# end of cluster 61
# 54 62
# cluster, fine grid size 0 18
# 0 16 61
# len(uhat), len(qhat) 18 18
# 3 number of flagged cells
# [ 59.  60.  61.]
# start of cluster 57
# end of cluster 63
# 56 64
# cluster, fine grid size 0 18
# 0 16 63
# len(uhat), len(qhat) 18 18
# 3 number of flagged cells
# [ 61.  62.  63.]
# start of cluster 59
# end of cluster 65
# 58 66
# cluster, fine grid size 0 18
# 0 16 65
# len(uhat), len(qhat) 18 18
# 3 number of flagged cells
# [ 63.  64.  65.]
# start of cluster 61
# end of cluster 67
# 60 68
# cluster, fine grid size 0 18
# 0 16 67
# len(uhat), len(qhat) 18 18
# 3 number of flagged cells
# [ 65.  66.  67.]
# start of cluster 63
# end of cluster 69
# 62 70
# cluster, fine grid size 0 18
# 0 16 69
# len(uhat), len(qhat) 18 18
# 3 number of flagged cells
# [ 67.  68.  69.]
# start of cluster 65
# end of cluster 71
# 64 72
# cluster, fine grid size 0 18
# 0 16 71
# len(uhat), len(qhat) 18 18
# 3 number of flagged cells
# [ 69.  70.  71.]
# start of cluster 67
# end of cluster 73
# 66 74
# cluster, fine grid size 0 18
# 0 16 73
# len(uhat), len(qhat) 18 18
# 3 number of flagged cells
# [ 71.  72.  73.]
# start of cluster 69
# end of cluster 75
# 68 76
# cluster, fine grid size 0 18
# 0 16 75
# len(uhat), len(qhat) 18 18
# 3 number of flagged cells
# [ 73.  74.  75.]
# start of cluster 71
# end of cluster 77
# 70 78
# cluster, fine grid size 0 18
# 0 16 77
# len(uhat), len(qhat) 18 18
# 3 number of flagged cells
# [ 75.  76.  77.]
# start of cluster 73
# end of cluster 79
# 72 80
# cluster, fine grid size 0 18
# 0 16 79
# len(uhat), len(qhat) 18 18
# 3 number of flagged cells
# [ 77.  78.  79.]
# start of cluster 75
# end of cluster 81
# 74 82
# cluster, fine grid size 0 18
# 0 16 81
# len(uhat), len(qhat) 18 18
# 3 number of flagged cells
# [ 79.  80.  81.]
# start of cluster 77
# end of cluster 83
# 76 84
# cluster, fine grid size 0 18
# 0 16 83
# len(uhat), len(qhat) 18 18
# 3 number of flagged cells
# [ 81.  82.  83.]
# start of cluster 79
# end of cluster 85
# 78 86
# cluster, fine grid size 0 18
# 0 16 85
# len(uhat), len(qhat) 18 18
# 3 number of flagged cells
# [ 83.  84.  85.]
# start of cluster 81
# end of cluster 87
# 80 88
# cluster, fine grid size 0 18
# 0 16 87
# len(uhat), len(qhat) 18 18
# 3 number of flagged cells
# [ 85.  86.  87.]
# start of cluster 83
# end of cluster 89
# 82 90
# cluster, fine grid size 0 18
# 0 16 89
# len(uhat), len(qhat) 18 18
# 3 number of flagged cells
# [ 87.  88.  89.]
# start of cluster 85
# end of cluster 91
# 84 92
# cluster, fine grid size 0 18
# 0 16 91
# len(uhat), len(qhat) 18 18
# 3 number of flagged cells
# [ 89.  90.  91.]
# start of cluster 87
# end of cluster 93
# 86 94
# cluster, fine grid size 0 18
# 0 16 93
# len(uhat), len(qhat) 18 18
# 3 number of flagged cells
# [ 91.  92.  93.]
# start of cluster 89
# end of cluster 95
# 88 96
# cluster, fine grid size 0 18
# 0 16 95
# len(uhat), len(qhat) 18 18
# 3 number of flagged cells
# [ 93.  94.  95.]
# start of cluster 91
# end of cluster 97
# 90 98
# cluster, fine grid size 0 18
# 0 16 97
# len(uhat), len(qhat) 18 18
# 3 number of flagged cells
# [ 95.  96.  97.]
# start of cluster 93
# end of cluster 99
# 92 100
# cluster, fine grid size 0 18
# 0 16 99
# len(uhat), len(qhat) 18 18
# 3 number of flagged cells
# [ 97.  98.  99.]
# start of cluster 95
# end of cluster 99
# 94 100
# cluster, fine grid size 0 14
# 0 12 99
# len(uhat), len(qhat) 14 14
# 0 number of flagged cells
# 0 number of flagged cells
# 0 number of flagged cells
# 0 number of flagged cells
# 0 number of flagged cells
# 0 number of flagged cells
# 0 number of flagged cells
# 0 number of flagged cells
# 0 number of flagged cells
# 0 number of flagged cells
# 0 number of flagged cells
# 0 number of flagged cells
# 0 number of flagged cells
# 0 number of flagged cells
# 0 number of flagged cells
# 0 number of flagged cells
# 0 number of flagged cells
# 0 number of flagged cells
# 0 number of flagged cells
# 0 number of flagged cells
# 0 number of flagged cells
# 0 number of flagged cells
# 0 number of flagged cells
# 0 number of flagged cells
# 0 number of flagged cells
# 0 number of flagged cells
# 0 number of flagged cells
# 0 number of flagged cells
# 0 number of flagged cells
# 0 number of flagged cells
# 0 number of flagged cells
# 0 number of flagged cells
# 0 number of flagged cells
# 0 number of flagged cells
# 0 number of flagged cells
# 0 number of flagged cells
# 0 number of flagged cells
# 0 number of flagged cells
# 0 number of flagged cells
# 0 number of flagged cells
# 0 number of flagged cells
# 0 number of flagged cells
# 0 number of flagged cells
# 0 number of flagged cells
# 0 number of flagged cells
# 0 number of flagged cells
# 0 number of flagged cells
# 0 number of flagged cells
# 0 number of flagged cells
# 0 number of flagged cells
# 0 number of flagged cells
# 0 number of flagged cells
# 0 number of flagged cells
# 0 number of flagged cells
# 0 number of flagged cells
# 0 number of flagged cells
# 0 number of flagged cells
# 0 number of flagged cells
# 0 number of flagged cells
# 0 number of flagged cells
# 0 number of flagged cells
# 0 number of flagged cells
# 0 number of flagged cells
# 0 number of flagged cells
# 0 number of flagged cells
# 0 number of flagged cells
# 0 number of flagged cells
# 0 number of flagged cells
# 0 number of flagged cells
# 0 number of flagged cells
# 0 number of flagged cells
# 0 number of flagged cells
# 0 number of flagged cells
# 0 number of flagged cells
# 0 number of flagged cells
# (-0.5, 1.5)

# %%
plot(xc,q0)
ylim(-0.1,1.1)
plt.figure(2)
plot(xc,u_fnc(xc))

# %%
def no_amr_color(u_fnc,q0,xc,tfinal,nsteps):
    # q0 = initial condition evaluated on coarse grid (cell averages)
    # u_fnc = a function name evaluating the coefficient function u at the grid points
    # u = velocity (coefficient) function, u[i] is cell-centered value in cell [i],
    #     currently evaluated at cell-midpoint
    # xc = coarse grid, domain [a,b] is divided into mx cells, and xc[i] is the mid-point of cell i
        
    dx = xc[1]- xc[0]             # length of cells in (given) coasrse grid
    dt = float(tfinal)/nsteps   # length of time-step
    u = u_fnc(xc)
    
    mx_c = len(xc)              # number of grid cells in coarse grid
    
    # Step 1: initalize coarse grid values q0 and u: Done before calling this function
    qn = q0
    
    for istep in range(nsteps):
        
    
        # Step 2: Solve problem on coarse grid for single time step
        #         Done by calling a function 'color_onestep', which advances the solution on a given grid
        #         with spacing dx, over a single time step of length dt, returns solution with two ghost cell
        #         values on each side
        qnp = color_onestep(u,qn,dt,dx)
        qn = qnp[2:mx_c+2]
        
        plt.figure(istep) 
        plot(xc,qn)
        plt.show()
        ylim([-0.5,1.5])
        
    return qn

# %%
qnew = no_amr_color(u_fnc,q0,xc,tfinal,nsteps)
